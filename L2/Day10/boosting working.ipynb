# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Combines Lot of weak learners to make predictions
# ## 2. Some Stumps are given more weights than others based on error rate
# ## 3. Each stump is made by taking previous stump's error in consideration
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 1. Sample weight is to be assigned to every Datapoint which will be  = 1/ total number of samples
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Now we will calculate the Ginni Index for the individual STUMPS
# ## 2. Stump with Lowest GINNI score will be the First stump in the Forest
# ## 3. After First stump has been identified, the Sample weight given to the fisrt Stump will be updated based on Error ot has in prediction
# ## 4.
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Calculating the Error for 1 Stump to update the weights, So
# # Total Error = Sum of Weights for the Incorrectly predicted Samples
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Wrongly Predicted values are given Increased weights and for correctly predicted values weights are reduced using the Given Below Formulae
# ![image.png](attachment:image.png)

# %% [markdown]
# ## The NEW SAMPLE WEIGHT is  = 1/8 * e(0.42)
# ## The NEW SAMPLE WEIGHTS gotten from the above fromulae gets updated under the Sample weight assigned to each record
#
# ## The Modified Sample weights are used to make the next Stump in the Forest
