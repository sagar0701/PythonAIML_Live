# %%
# BIGMART DATA

# Missing:
1. Weight: Mean, Median, [Item_Type-Average by Item type, Avergae of weights w.r.t Item Identifer, Item Visiblity]

#################################   
2. outlet size: Mode, 
    
Outlet_Location_Type  Outlet_Type        Outlet_Size
Tier 1                Grocery Store      Small           880
                      Supermarket Type1  Medium         1550
                                         Small          1550
        
Tier 2                Supermarket Type1  Small          1550

Tier 3                Supermarket Type1  High           1553
                      Supermarket Type2  Medium         1546
                      Supermarket Type3  Medium         1559
    
############################
Outlet_Size  Outlet_Location_Type  Outlet_Type      
High         Tier 3                Supermarket Type1    1553

Medium       Tier 1                Supermarket Type1    1550
             Tier 3                Supermarket Type2    1546
                                   Supermarket Type3    1559
        
Small        Tier 1                Grocery Store         880
                                   Supermarket Type1    1550
             Tier 2                Supermarket Type1    1550
    
###############################

1. Item_Visibility has outliers :Item_Visibility has 0
    Based on Item_Identifer
    Categorise the Data based on values
    Continue with regular column woth 0 and outlier treated

#################################
# Extras
1. Item_Fat_Content-  has ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']  

###########################3
# Feature Engineering
1. Age of store

###############
OUT013             High           932
OUT018             Medium         928
OUT019             Small          528
OUT027             Medium         935
OUT035             Small          930
OUT046             Small          930
OUT049             Medium         930

# %% [markdown]
# #### K-Nearest Neighbor Classifier/ Regressor
#
# 1. Distance of new Datapoint will be calculated w.r.t data
# 2. Distances wil be sorted
# 3. Datapoint closest to the new datapoint will be considered - number of neighbors to be consodered for decision
# 4. for example if 5 nearest neighbors are considered, than :
#             Classification : Max Voted class will be output
#             Regression : Average of 5 neighbors will be output
#
#
#  ** To find Optimal Value of K : Grid Search CV
#  ** Value of w.r.t error we are getting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Support Vector Machine :
#
# 1. not genreally used for Regression
# 2. only used for classification that too on big dataset
# 3. Looks for maximised margin between the support vector and hyperplane alos having less error
# 4. Kernel for Kernel trick - projects data to next dimension to find optimal hyperplane
# 5. Gamma parameter  - High Gamma value : means consider few datapints for hyperplane
#                     - Low gamma value : consider more numer of datapoints for hyperplane
# 6. Cost function - High Cost : Low Error - Error in SVM are also refered as Slack Values --Hard Margin
#                    Low Cost : High error - Soft Margin -

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)
# ![image-5.png](attachment:image-5.png)
# ![image-4.png](attachment:image-4.png)
# ![image-6.png](attachment:image-6.png)

# %%
from sklearn.neighbors import KNeighborsClassifier # KNeighborsRegressor
from sklearn.svm import SVC # SVR

# %% [markdown]
# # **Problem Statement for Car Evaluation Dataset**
#
#
# ### Car Evaluation Database
# It is a multi-class classification problem.
# Task is to classify our dataset into **4 classes** : Unacceptable, Acceptable, Good, Very-Good.
#
# ### Independent variables
#
#  1. buying : buying price
#  2. maint : maintenance price
#  3. doors : number of doors
#  4. persons : capacity in terms of persons to carry
#  5. lug_boot : the size of luggage boot
#  6. safety: estimated safety of the car
#
# ### Target Variable
#  1. Class

# %%
#
