# %%
# %config Completer.use_jedi = False #for switching on auto complete

# %%
from sklearn.datasets import load_boston

# %%
df=load_boston()

# %%
x=df.data

# %%
y=df.target

# %%
from sklearn.model_selection import train_test_split

# %%
#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0)

# %%
# standarise data
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
std.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train_std=std.transform(x_train)
x_test_std=std.transform(x_test)

# %%
from tensorflow import keras

# %%
# build network
from keras.models import Sequential
from keras.layers import Dense

# %%
model=Sequential()
model.add(Dense(4,activation='relu'))#first hidden layer
model.add(Dense(2,activation='relu'))#2nd hidden layer
model.add(Dense(1,activation='relu'))#output layer

# %%
model.compile(loss='mse',optimizer='adam',metrics=['mae'])

# %%
from livelossplot import PlotLossesKeras

# %%
model.fit(x_train_std,y_train,epochs=500,validation_data=(x_test_std,y_test),callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:   10.803, max:  591.797, cur:   10.803)
# 	validation       	 (min:   22.919, max:  573.753, cur:   22.919)
# mae
# 	training         	 (min:    2.358, max:   22.466, cur:    2.360)
# 	validation       	 (min:    3.376, max:   22.146, cur:    3.378)
# 12/12 [==============================] - 0s 32ms/step - loss: 10.8034 - mae: 2.3603 - val_loss: 22.9194 - val_mae: 3.3782

# %%
x_train.shape
# Out:
# (379, 13)

# %%
379/10
# Out:
# 37.9
